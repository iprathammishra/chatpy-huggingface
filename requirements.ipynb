# %% [markdown]
# ## You will need the following libraries to get started:
# * **transformers**
# * **streamlit**
#
# For **transformers**: -
# `
#     pip install transformers
# `
#
# For **streamlit**: -
# `
#     pip install streamlit
# `
#
# *Note: These requirements are staged for version 1.0.0.*
